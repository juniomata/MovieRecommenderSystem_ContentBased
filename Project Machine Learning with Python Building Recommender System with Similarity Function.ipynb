# %% [markdown]
# # Building Movie Recommender System with Similarity Function

# %%
# Import library
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Data Unloading and Checking

# %%
# Read datasets
rating_df = pd.read_csv('https://dqlab-dataset.s3-ap-southeast-1.amazonaws.com/movie_rating_df.csv')
name_df = pd.read_csv('https://dqlab-dataset.s3-ap-southeast-1.amazonaws.com/actor_name.csv')
director_df = pd.read_csv('https://dqlab-dataset.s3-ap-southeast-1.amazonaws.com/directors_writers.csv')

# %%
# Show MOVIE RATING dataset
rating_df.sample(5)
# Out:
#             tconst titleType                  primaryTitle  \
# 587210   tt4118906   tvMovie  Special Drama: Maison Ikkoku
# 734542   tt8852046     movie                   The Meeting
# 6918     tt0024205     movie          Kazdemu wolno kochac
# 334771  tt10064354     movie                        Inland
# 502040   tt2301241     short           The Winners' Circle
#
#                          originalTitle  isAdult  startYear  endYear  \
# 587210  Supesharu dorama: Mezon Ikkoku        0     2007.0      NaN
# 734542                     The Meeting        0     2018.0      NaN
# 6918              Kazdemu wolno kochac        0     1933.0      NaN
# 334771                          Inland        0     2019.0      NaN
# 502040             The Winners' Circle        0     2010.0      NaN
#
#         runtimeMinutes                genres  averageRating  numVotes
# 587210           107.0  Comedy,Drama,Romance            4.9         7
# 734542            96.0                   NaN            7.2         9
# 6918              80.0        Comedy,Romance            6.6        53
# 334771            95.0                   NaN            7.9        18
# 502040            14.0     Documentary,Short            7.9        16

# %%
# Show columns type of  MOVIE RATING dataset
rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 751614 entries, 0 to 751613
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          751614 non-null  object
#  1   titleType       751614 non-null  object
#  2   primaryTitle    751614 non-null  object
#  3   originalTitle   751614 non-null  object
#  4   isAdult         751614 non-null  int64
#  5   startYear       751614 non-null  float64
#  6   endYear         16072 non-null   float64
#  7   runtimeMinutes  751614 non-null  float64
#  8   genres          486766 non-null  object
#  9   averageRating   751614 non-null  float64
#  10  numVotes        751614 non-null  int64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 63.1+ MB

# %%
# Show ACTOR NAME dataset
name_df.sample(5)
# Out:
#         nconst              primaryName birthYear deathYear  \
# 300  nm4287983          Brianna Kondrat        \N        \N
# 396  nm7232369            Teresa Bonner        \N        \N
# 515  nm2884073           Ngan-Ying Poon        \N        \N
# 244  nm9480005  Samuel Gagnon-Thibodeau        \N        \N
# 297  nm1901214            Naoki Katakai        \N        \N
#
#                                     primaryProfession  \
# 300   miscellaneous,art_department,production_manager
# 396                                          producer
# 515       actress,costume_department,costume_designer
# 244                                               NaN
# 297  art_department,animation_department,art_director
#
#                               knownForTitles
# 300  tt1835129,tt1299368,tt1693679,tt1918727
# 396                                tt4569160
# 515  tt0311792,tt0104553,tt0096078,tt0237501
# 244                                tt7735196
# 297  tt0268256,tt0397042,tt0884870,tt0232531

# %%
# Show columns type of  ACTOR NAME dataset
name_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nconst             1000 non-null   object
#  1   primaryName        1000 non-null   object
#  2   birthYear          1000 non-null   object
#  3   deathYear          1000 non-null   object
#  4   primaryProfession  891 non-null    object
#  5   knownForTitles     1000 non-null   object
# dtypes: object(6)
# memory usage: 47.0+ KB

# %%
# Show DIRECTOR-WRITER dataset
director_df.sample(5)
# Out:
#         tconst       director_name  \
# 37   tt0060910        Otakar Vávra
# 685  tt1783244       Jerzy Hoffman
# 929  tt6450804          Tim Miller
# 601  tt1339050        Jordan Clark
# 779  tt2515134  Thomas K. Phillips
#
#                                            writer_name
# 37                       Frantisek Hrubín,Otakar Vávra
# 685                       Jerzy Hoffman,Jaroslaw Sokól
# 929  Charles H. Eglee,James Cameron,Josh Friedman,D...
# 601                  Jordan Clark,Janice Santos Valdez
# 779                   Thomas K. Phillips,Tim O'Connell

# %%
# Show columns type of  DIRECTOR-WRITER dataset
director_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         986 non-null    object
#  1   director_name  986 non-null    object
#  2   writer_name    986 non-null    object
# dtypes: object(3)
# memory usage: 23.2+ KB

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# #### Choosing relevants features
# We don't need all the columns of Actor Name dataset to be processed. So, we select columns that relevant to the cases. Those columns are:
# - `nconst`
# - `primaryName`
# - `knownForTitles`

# %%
name_df = name_df[['nconst','primaryName','knownForTitles']]
name_df.head()
# Out:
#        nconst          primaryName                           knownForTitles
# 0   nm1774132    Nathan McLaughlin  tt0417686,tt1713976,tt1891860,tt0454839
# 1  nm10683464        Bridge Andrew                                tt7718088
# 2   nm1021485    Brandon Fransvaag                                tt0168790
# 3   nm6940929   Erwin van der Lely                                tt4232168
# 4   nm5764974  Svetlana Shypitsyna                                tt3014168

# %% [markdown]
# #### Convert data into List
# This process aims to simplify directors and writers accessing/subsetting since we have multiple directors and writers in one column

# %%
# Convert director_name to list
director_df['director_name'] = director_df['director_name'].apply(lambda row: row.split(','))
director_df['writer_name'] = director_df['writer_name'].apply(lambda row: row.split(','))

# Show top 5 data
director_df.head()
# Out:
#       tconst                      director_name  \
# 0  tt0011414                   [David Kirkland]
# 1  tt0011890                [Roy William Neill]
# 2  tt0014341  [Buster Keaton, John G. Blystone]
# 3  tt0018054                 [Cecil B. DeMille]
# 4  tt0024151                      [James Cruze]
#
#                                          writer_name
# 0                         [John Emerson, Anita Loos]
# 1   [Arthur F. Goodrich, Burns Mantle, Mary Murillo]
# 2  [Jean C. Havez, Clyde Bruckman, Joseph A. Mitc...
# 3                                [Jeanie Macpherson]
# 4               [Max Miller, Wells Root, Jack Jevne]

# %% [markdown]
# #### One to One Correspondence
#
# Of course an actor can play in more than a film. Then, a table of 1-1 relation to each of the movies' title is necessary. We have to unnest the table.

# %%
# Variation checking
name_df['knownForTitles'].apply(lambda x: len(x.split(','))).unique()

# Covert knownForTitles menjadi list of list
name_df['knownForTitles'] = name_df['knownForTitles'].apply(lambda x: x.split(','))

# Show top 5 data
name_df.head()
# Out:
#        nconst          primaryName  \
# 0   nm1774132    Nathan McLaughlin
# 1  nm10683464        Bridge Andrew
# 2   nm1021485    Brandon Fransvaag
# 3   nm6940929   Erwin van der Lely
# 4   nm5764974  Svetlana Shypitsyna
#
#                                  knownForTitles
# 0  [tt0417686, tt1713976, tt1891860, tt0454839]
# 1                                   [tt7718088]
# 2                                   [tt0168790]
# 3                                   [tt4232168]
# 4                                   [tt3014168]

# %%
# prepare the bucket for dataframe
df_uni = []

for x in ['knownForTitles']:
    # repeat index so we have name of index as many as the knownForTitles list length in a row
    idx = name_df.index.repeat(name_df['knownForTitles'].str.len())

    # split every list values in a row and concat to the another rows as dataframe
    df1 = pd.DataFrame({
        x: np.concatenate(name_df[x].values)
    })

    # change the index to idx
    df1.index = idx

    # for every dataframe formed, add to the bucket
    df_uni.append(df1)

# %%
# concatting data
df_concat = pd.concat(df_uni, axis=1)

# join with the value of original dataframe
unnested_df = df_concat.join(name_df.drop(['knownForTitles'], 1), how='left')

# make the column order same as original dataframe
unnested_df = unnested_df[name_df.columns.tolist()]
unnested_df
# Out:
#          nconst        primaryName knownForTitles
# 0     nm1774132  Nathan McLaughlin      tt0417686
# 0     nm1774132  Nathan McLaughlin      tt1713976
# 0     nm1774132  Nathan McLaughlin      tt1891860
# 0     nm1774132  Nathan McLaughlin      tt0454839
# 1    nm10683464      Bridge Andrew      tt7718088
# ..          ...                ...            ...
# 998   nm5245804      Eliza Jenkins      tt1464058
# 999   nm0948460         Greg Yolen      tt0436869
# 999   nm0948460         Greg Yolen      tt0476663
# 999   nm0948460         Greg Yolen      tt0109723
# 999   nm0948460         Greg Yolen      tt0364484
#
# [1918 rows x 3 columns]

# %% [markdown]
# #### Group primaryName as list group by knownForTitles
#
# Next, we will group the player column because what we need to do movie recommendation is the movie level

# %%
unnested_drop = unnested_df.drop(['nconst'], axis=1)

df_uni2 = []

for col in ['primaryName']:
    # PrimaryName feature aggregation
    dfi = unnested_drop.groupby(['knownForTitles'])[col].apply(list)
    df_uni2.append(dfi)
    
df_grouped = pd.concat(df_uni2, axis=1).reset_index()
df_grouped.columns = ['knownForTitles','cast_name']
df_grouped
# Out:
#      knownForTitles           cast_name
# 0         tt0008125    [Charles Harley]
# 1         tt0009706    [Charles Harley]
# 2         tt0010304  [Natalie Talmadge]
# 3         tt0011414  [Natalie Talmadge]
# 4         tt0011890  [Natalie Talmadge]
# ...             ...                 ...
# 1893      tt9610496  [Stefano Baffetti]
# 1894      tt9714030        [Kevin Kain]
# 1895      tt9741820   [Caroline Plyler]
# 1896      tt9759814     [Ethan Francis]
# 1897      tt9856236     [Nuala Maguire]
#
# [1898 rows x 2 columns]

# %% [markdown]
# #### Join table

# %%
# join df_grouped with rating_df
base_df = pd.merge(df_grouped, rating_df, left_on='knownForTitles', right_on='tconst', how='inner')

# join base_df with director_df
base_df = pd.merge(base_df, director_df, left_on='tconst', right_on='tconst', how='left')

base_df.head()
# Out:
#   knownForTitles           cast_name     tconst titleType  \
# 0      tt0011414  [Natalie Talmadge]  tt0011414     movie
# 1      tt0011890  [Natalie Talmadge]  tt0011890     movie
# 2      tt0014341  [Natalie Talmadge]  tt0014341     movie
# 3      tt0018054     [Reeka Roberts]  tt0018054     movie
# 4      tt0024151     [James Hackett]  tt0024151     movie
#
#              primaryTitle           originalTitle  isAdult  startYear  \
# 0         The Love Expert         The Love Expert        0     1920.0
# 1               Yes or No               Yes or No        0     1920.0
# 2         Our Hospitality         Our Hospitality        0     1923.0
# 3       The King of Kings       The King of Kings        0     1927.0
# 4  I Cover the Waterfront  I Cover the Waterfront        0     1933.0
#
#    endYear  runtimeMinutes                   genres  averageRating  numVotes  \
# 0      NaN            60.0           Comedy,Romance            4.9       136
# 1      NaN            72.0                      NaN            6.3         7
# 2      NaN            65.0  Comedy,Romance,Thriller            7.8      9621
# 3      NaN           155.0  Biography,Drama,History            7.3      1826
# 4      NaN            80.0            Drama,Romance            6.3       455
#
#                        director_name  \
# 0                   [David Kirkland]
# 1                [Roy William Neill]
# 2  [Buster Keaton, John G. Blystone]
# 3                 [Cecil B. DeMille]
# 4                      [James Cruze]
#
#                                          writer_name
# 0                         [John Emerson, Anita Loos]
# 1   [Arthur F. Goodrich, Burns Mantle, Mary Murillo]
# 2  [Jean C. Havez, Clyde Bruckman, Joseph A. Mitc...
# 3                                [Jeanie Macpherson]
# 4               [Max Miller, Wells Root, Jack Jevne]

# %% [markdown]
# #### Cleaning data
#
# In this step, we will handle null values and drop unrequired features

# %%
# check null values
base_df.isnull().sum()
# Out:
# knownForTitles      0
# cast_name           0
# tconst              0
# titleType           0
# primaryTitle        0
# originalTitle       0
# isAdult             0
# startYear           0
# endYear           950
# runtimeMinutes      0
# genres            315
# averageRating       0
# numVotes            0
# director_name      74
# writer_name        74
# dtype: int64

# %% [markdown]
# Knowing some features have null values, we have to handle them by filling `Unknown` value

# %%
base_fill = base_df

# %%
# Fill NULL value with 'Unknown'
base_fill['genres'] = base_fill['genres'].fillna('Unknown')
base_fill[['director_name','writer_name']] = base_fill[['director_name','writer_name']].fillna('unknown')

# %%
# Genres feature has nultiple values, so it's better to make it list of list
base_fill['genres'] = base_fill['genres'].apply(lambda x: x.split(','))

# %%
# Drop knownForTitles, tconst, isAdult, endYear, originalTitle
base_drop = base_fill.drop(['knownForTitles','tconst','isAdult','endYear','originalTitle'], axis=1)

base_drop = base_drop[['primaryTitle','titleType','startYear','runtimeMinutes','genres','averageRating','numVotes','cast_name','director_name','writer_name']]

base_drop.columns = ['title','type','start','duration','genres','rating','votes','cast_name','director_name','writer_name']
base_drop.head()
# Out:
#                     title   type   start  duration  \
# 0         The Love Expert  movie  1920.0      60.0
# 1               Yes or No  movie  1920.0      72.0
# 2         Our Hospitality  movie  1923.0      65.0
# 3       The King of Kings  movie  1927.0     155.0
# 4  I Cover the Waterfront  movie  1933.0      80.0
#
#                         genres  rating  votes           cast_name  \
# 0            [Comedy, Romance]     4.9    136  [Natalie Talmadge]
# 1                    [Unknown]     6.3      7  [Natalie Talmadge]
# 2  [Comedy, Romance, Thriller]     7.8   9621  [Natalie Talmadge]
# 3  [Biography, Drama, History]     7.3   1826     [Reeka Roberts]
# 4             [Drama, Romance]     6.3    455     [James Hackett]
#
#                        director_name  \
# 0                   [David Kirkland]
# 1                [Roy William Neill]
# 2  [Buster Keaton, John G. Blystone]
# 3                 [Cecil B. DeMille]
# 4                      [James Cruze]
#
#                                          writer_name
# 0                         [John Emerson, Anita Loos]
# 1   [Arthur F. Goodrich, Burns Mantle, Mary Murillo]
# 2  [Jean C. Havez, Clyde Bruckman, Joseph A. Mitc...
# 3                                [Jeanie Macpherson]
# 4               [Max Miller, Wells Root, Jack Jevne]

# %%
base_drop.isnull().sum()
# Out:
# title            0
# type             0
# start            0
# duration         0
# genres           0
# rating           0
# votes            0
# cast_name        0
# director_name    0
# writer_name      0
# dtype: int64

# %% [markdown]
# ## Creating Content-based Recommender System

# %% [markdown]
# #### Metadata Classification

# %%
# Classify data by title, cast_name, genres, director_name, dan writer_name
feature_df = base_drop[['title', 'cast_name', 'genres', 'director_name', 'writer_name']]

# Show data
feature_df.head()
# Out:
#                     title           cast_name                       genres  \
# 0         The Love Expert  [Natalie Talmadge]            [Comedy, Romance]
# 1               Yes or No  [Natalie Talmadge]                    [Unknown]
# 2         Our Hospitality  [Natalie Talmadge]  [Comedy, Romance, Thriller]
# 3       The King of Kings     [Reeka Roberts]  [Biography, Drama, History]
# 4  I Cover the Waterfront     [James Hackett]             [Drama, Romance]
#
#                        director_name  \
# 0                   [David Kirkland]
# 1                [Roy William Neill]
# 2  [Buster Keaton, John G. Blystone]
# 3                 [Cecil B. DeMille]
# 4                      [James Cruze]
#
#                                          writer_name
# 0                         [John Emerson, Anita Loos]
# 1   [Arthur F. Goodrich, Burns Mantle, Mary Murillo]
# 2  [Jean C. Havez, Clyde Bruckman, Joseph A. Mitc...
# 3                                [Jeanie Macpherson]
# 4               [Max Miller, Wells Root, Jack Jevne]

# %%
simple_df = base_drop[['title', 'cast_name', 'genres', 'director_name', 'writer_name']]

# %% [markdown]
# #### Strip spaces of each rows and elements

# %%
def sanitize(x):
    try:
        #kalau cell berisi list
        if isinstance(x, list):
            return [i.replace(' ','').lower() for i in x]
        #kalau cell berisi string
        else:
            return [x.replace(' ','').lower()]
    except:
        print(x)
             
feature_cols = ['cast_name','genres','writer_name','director_name']

# apply function sanitize 
for col in feature_cols:
    feature_df[col] = feature_df[col].apply(sanitize)
# Out:
# C:\Users\Junio\anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %% [markdown]
# #### Merge all feature as one sentence for each title

# %%
def soup_feature(x):
    return ' '.join(x['cast_name']) + ' ' + ' '.join(x['genres']) + ' ' + ' '.join(x['director_name']) + ' ' + ' '.join(x['writer_name'])

# making to one column
feature_df['soup'] = feature_df.apply(soup_feature, axis=1)
# Out:
# C:\Users\Junio\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# #### Prepare CountVectorizer and fit to the soup above

# %%
# define CountVectorizer dan change the previous soup to vector
countvec = CountVectorizer(stop_words='english')
count_matrix = countvec.fit_transform(feature_df['soup'])

print(count)
print(count_matrix.shape)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words='english',
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)
# (1060, 10026)

# %% [markdown]
# #### Making similarity model

# %% [markdown]
# In this step, we want to calculate cosine similarity score of each title pairs (based on every combination), in other words we will make 675x675 matrix, where cell in i and j column show the similarity score between i and j. The diagonal value will be 1, since
#
# The formula of cosine similarity calculation between 2 text:
#
# $cosine(x,y)=\frac{x.y^T}{||x||.||y||}$
#
# The output will be the range of -1 to 1. The closer the score to 1 means the two entities are very similar. The closer the score to -1 means the two entities are very different.

# %%
# Import cosine_similarity
from sklearn.metrics.pairwise import cosine_similarity

# Gunakan cosine_similarity antara count_matrix 
cosine_sim = cosine_similarity(count_matrix, count_matrix)

cosine_sim
# Out:
# array([[1.        , 0.15430335, 0.35355339, ..., 0.        , 0.        ,
#         0.13608276],
#        [0.15430335, 1.        , 0.10910895, ..., 0.        , 0.        ,
#         0.        ],
#        [0.35355339, 0.10910895, 1.        , ..., 0.        , 0.08703883,
#         0.09622504],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.08703883, ..., 0.        , 1.        ,
#         0.10050378],
#        [0.13608276, 0.        , 0.09622504, ..., 0.        , 0.10050378,
#         1.        ]])

# %% [markdown]
# #### Content based recommender system

# %%
indices = pd.Series(feature_df.index, index=feature_df['title']).drop_duplicates()

def content_recommender(title):
    #mendapatkan index dari judul film (title) yang disebutkan
    idx = indices[title]

    #menjadikan list dari array similarity cosine sim 
    #hint: cosine_sim[idx]
    sim_scores = list(enumerate(cosine_sim[idx]))

    #mengurutkan film dari similarity tertinggi ke terendah
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    #untuk mendapatkan list judul dari item kedua sampe ke 11
    sim_scores = sim_scores[1:11]

    #mendapatkan index dari judul-judul yang muncul di sim_scores
    movie_indices = [i[0] for i in sim_scores]

    #dengan menggunakan iloc, kita bisa panggil balik berdasarkan index dari movie_indices
    return base_drop.iloc[movie_indices]

# %% [markdown]
# Please replace ### with the movie name on the function `content_recommender('###')`. The movie reccomendation based on the movie you input will appear

# %%
# Apply the function
content_recommender('Iron Man')
# Out:
#                       title   type   start  duration  \
# 726           Black Panther  movie  2018.0     134.0
# 873       X-Men: Apocalypse  movie  2016.0     144.0
# 511               Star Trek  movie  2009.0     127.0
# 611      X-Men: First Class  movie  2011.0     131.0
# 494                 Ant-Man  movie  2015.0     117.0
# 791  Spider-Man: Homecoming  movie  2017.0     133.0
# 466     Alita: Battle Angel  movie  2019.0     122.0
# 637               Inception  movie  2010.0     148.0
# 649              Battleship  movie  2012.0     131.0
# 877          Thor: Ragnarok  movie  2017.0     130.0
#
#                           genres  rating    votes  \
# 726  [Action, Adventure, Sci-Fi]     7.3   575851
# 873  [Action, Adventure, Sci-Fi]     6.9   377709
# 511  [Action, Adventure, Sci-Fi]     7.9   567224
# 611  [Action, Adventure, Sci-Fi]     7.7   629609
# 494  [Action, Adventure, Comedy]     7.3   540644
# 791  [Action, Adventure, Sci-Fi]     7.4   479292
# 466  [Action, Adventure, Sci-Fi]     7.3   202735
# 637  [Action, Adventure, Sci-Fi]     8.8  1950039
# 649  [Action, Adventure, Sci-Fi]     5.8   230468
# 877  [Action, Adventure, Comedy]     7.9   544539
#
#                         cast_name        director_name  \
# 726             [Robert E. Evans]       [Ryan Coogler]
# 873              [Frank Maudsley]       [Bryan Singer]
# 511  [Matthew Fuchs, Aida Caefer]        [J.J. Abrams]
# 611                 [Aida Caefer]     [Matthew Vaughn]
# 494            [Francesco Cadoni]        [Peyton Reed]
# 791              [Frank Maudsley]          [Jon Watts]
# 466                [Jeff Bottoms]   [Robert Rodriguez]
# 637               [Dan Churchill]  [Christopher Nolan]
# 649             [Robert E. Evans]         [Peter Berg]
# 877            [Francesco Cadoni]      [Taika Waititi]
#
#                                            writer_name
# 726  [Stan Lee, Jack Kirby, Ryan Coogler, Joe Rober...
# 873  [Stan Lee, Jack Kirby, Simon Kinberg, Bryan Si...
# 511    [Gene Roddenberry, Roberto Orci, Alex Kurtzman]
# 611  [Stan Lee, Jack Kirby, Ashley Miller, Zack Ste...
# 494  [Stan Lee, Larry Lieber, Jack Kirby, Edgar Wri...
# 791  [Stan Lee, Jack Kirby, Joe Simon, Jonathan Gol...
# 466  [James Cameron, Laeta Kalogridis, Yukito Kishiro]
# 637                                [Christopher Nolan]
# 649                         [Jon Hoeber, Erich Hoeber]
# 877  [Stan Lee, Larry Lieber, Jack Kirby, Craig Kyl...
